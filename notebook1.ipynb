# %% [markdown]
# # Notebook 1
# ## Introduction to Himalayan precipitation data
#
# This notebook introduces two precipiation datasets over the Upper Beas and Sutlej river basins, Himalayas. The aim is to give you a sense of differences between the two datasets (climate reanalysis and in-situ observations) but also a flavour of the complex spatio-temporal distribution of precpitation in this area.
#
# ### In-situ observations
#
# ### Climate reanalysis
#
# ## Experiment

# %% [markdown]
# ### 1. Import libraries

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# custom modules
from load import era5, beas_sutlej_gauges
from maps import study_areas

# %% [markdown]
# ### 2. Gauge data

# %%
gauge_ds = beas_sutlej_gauges.all_gauge_data(minyear=1980, maxyear=2011)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
study_areas.beas_sutlej_gauge_map()
# Out:
# Median elevation:  4666.5 m

# %%
# Missing data info

# %% [markdown]
# Plotting the data shows that

# %% [markdown]
# ### 3. ERA5 data

# %%
era5_ds = era5.download_data('beas_sutlej')
# Out:
# _Data/ERA5/combi_data_indus_10-2021.csv

# %% [markdown]
# ### 4. Seasonal changes

# %% [markdown]
# ### 5. High spatial variability
